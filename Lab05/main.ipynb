# %% [markdown]
# # Lab 06 — Transfer Learning with ResNet-50 on Tiny-ImageNet
#
# **Runtime:** `Runtime > Change runtime type > T4 GPU`

# %%
import torch

assert torch.cuda.is_available(), "GPU not available. Go to Runtime > Change runtime type > T4 GPU."
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"PyTorch: {torch.__version__}")
# Out:
# GPU: Tesla T4
# PyTorch: 2.10.0+cu128

# %%
import os

os.chdir("/content")
assert os.path.exists("train.py"), f"train.py not found in {os.getcwd()}"
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /content

# %%
# %pip install -q wandb datasets pyyaml

# %%
import wandb

WANDB_API_KEY = ""  # paste your key from wandb.ai/settings

wandb.login(key=WANDB_API_KEY)
wandb.init(entity="tmdgk115-sungkyunkwan-university", project="osai-lab05")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: WARNING [wandb.login()] Changing session credentials to explicit value for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/content/wandb/run-20260408_093434-u76uv4uf</code>
# Syncing run <strong><a href='https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05/runs/u76uv4uf' target="_blank">denim-fog-3</a></strong> to <a href='https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05' target="_blank">https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05</a>
#  View run at <a href='https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05/runs/u76uv4uf' target="_blank">https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05/runs/u76uv4uf</a>
# &lt;wandb.sdk.wandb_run.Run object at 0x7f4289249d00&gt;

# %%
# %run train.py
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">denim-fog-3</strong> at: <a href='https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05/runs/u76uv4uf' target="_blank">https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05/runs/u76uv4uf</a><br> View project at: <a href='https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05' target="_blank">https://wandb.ai/tmdgk115-sungkyunkwan-university/osai-lab05</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260408_093434-u76uv4uf/logs</code>
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# /content/train.py in <module>
#     169
#     170 if __name__ == "__main__":
# --> 171     main()
#
# /content/train.py in main()
#      45
#      46     # --- wandb ---
# ---> 47     run = wandb.init(
#      48         entity=cfg["wandb"]["team"],
#      49         project=cfg["wandb"]["project"],
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/wandb_init.py in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings, anonymous)
#    1593             wl._get_logger().exception("error in wandb.init()", exc_info=e)
#    1594
# -> 1595         get_sentry().reraise(e)
#
# /usr/local/lib/python3.12/dist-packages/wandb/analytics/sentry.py in reraise(self, exc)
#     188             _, _, tb = sys.exc_info()
#     189             if tb is not None and hasattr(exc, "with_traceback"):
# --> 190                 raise exc.with_traceback(tb)
#     191             raise exc
#     192
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/wandb_init.py in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings, anonymous)
#    1576                 init_telemetry.feature.server_side_derived_summary = True
#    1577
# -> 1578             run = wi.init(run_settings, run_config, run_printer)
#    1579
#    1580             # Set up automatic Weave integration if Weave is installed
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/wandb_init.py in init(self, settings, config, run_printer)
#    1029
#    1030         if error := ProtobufErrorHandler.to_exception(result.run_result.error):
# -> 1031             raise error
#    1032
#    1033         if not result.run_result.HasField("run"):
#
# CommError: Error uploading run: returned error 403: {"data":{"upsertBucket":null},"errors":[{"message":"permission denied","path":["upsertBucket"],"extensions":{"code":"PERMISSION_ERROR"}}]}

# %%
# Optional: evaluate the best checkpoint
# %run eval.py
# Out:
# === Parameter Counts ===
#   total                              :    1,547,528
#   trainable                          :    1,547,528
#   layer/backbone                     :    1,444,928
#   layer/classifier                   :      102,600
# === Evaluation Results ===
#   Loss : 2.0920
#   Top-1: 49.59%
